# %%
import pandas as pd
from pathlib import Path

p = Path("C:/Users/Usuario/Desktop/data-science/sumario-bot/data/principal/")
df = pd.read_excel('')

# %%
p = Path("C:/Users/Usuario/Desktop/data-science/sumario-bot/data/principal/")

# %%
for arquivo in p.glob("*.xlsx"):
    print(arquivo)
# Out:
# C:\Users\Usuario\Desktop\data-science\sumario-bot\data\principal\Dados_PRPG.xlsx
# C:\Users\Usuario\Desktop\data-science\sumario-bot\data\principal\dm-sidtec-lattes.xlsx
# C:\Users\Usuario\Desktop\data-science\sumario-bot\data\principal\dm-sidtec-output.xlsx
# C:\Users\Usuario\Desktop\data-science\sumario-bot\data\principal\dm-sidtec-process.xlsx
# C:\Users\Usuario\Desktop\data-science\sumario-bot\data\principal\INDICADORES.xlsx
# C:\Users\Usuario\Desktop\data-science\sumario-bot\data\principal\tbl-saego-prpg-global.xlsx
